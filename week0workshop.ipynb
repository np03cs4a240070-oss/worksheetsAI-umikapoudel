# %% [markdown]
# <a href="https://colab.research.google.com/github/np03cs4a240070-oss/worksheet1-umikapoudel/blob/main/week0workshop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Daily time (in hours): [study, entertainment, sleep]
time_data = [
(3.5, 2.0, 7.0), (5.0, 1.5, 6.5), (2.5, 3.0, 8.0),
(4.0, 2.0, 6.0), (1.5, 4.5, 9.0), (3.0, 2.5, 7.5),
(5.5, 1.0, 6.0), (2.0, 3.5, 8.5), (4.5, 2.0, 7.0),
(3.0, 3.0, 7.5), (6.0, 1.5, 6.0), (2.5, 4.0, 8.0),
(4.0, 2.5, 7.0), (5.0, 2.0, 6.5), (3.5, 2.5, 7.0)
]
#1 Create empty lists for study time classifications:
low = []
moderate = []
high = []
#Iterate over the time_data list and add each study hour to the appropriate category.
for study, entertainment, sleep in time_data:
    if study < 3:
      #Low: less than 3 hours.
        low.append(study)
    elif 3 <= study <= 5:
      #Moderate: between 3 and 5 hours.
        moderate.append(study)
    else:
      #High: more than 5 hours.
        high.append(study)
#3 Print the lists to verify the classifications.
print("Low (<3 hrs):", low)
print("Moderate (3–5 hrs):", moderate)
print("High (>5 hrs):", high)
# Out:
# Low (<3 hrs): [2.5, 1.5, 2.0, 2.5]
# Moderate (3–5 hrs): [3.5, 5.0, 4.0, 3.0, 4.5, 3.0, 4.0, 5.0, 3.5]
# High (>5 hrs): [5.5, 6.0]

# %%
#1. How many days had low study time?
#(a) Hint: Count the number of items in the low study list and print the result.
print("days which had low study time",len(low))
#2. How many days had moderate study time?
print("days which had moderate study time",len(moderate))
#3. How many days had high study time?
print("days which had high study time",len(high))
# Out:
# days which had low study time 4
# days which had moderate study time 9
# days which had high study time 2

# %%
#Convert each study hour value into minutes and store it in a new list called study_minutes.
#1. Iterate over the time_data list and apply the formula to the study hours.
study_minutes = []

# 2. Convert study hours to minutes
for study, entertainment, sleep in time_data:
  #(Formula: Minutes = Hours × 60)
    minutes = study * 60
    #2. Store the results in the new list.
    study_minutes.append(minutes)

#3. Print the converted values.
print("Study time in minutes:", study_minutes)
# Out:
# Study time in minutes: [210.0, 300.0, 150.0, 240.0, 90.0, 180.0, 330.0, 120.0, 270.0, 180.0, 360.0, 150.0, 240.0, 300.0, 210.0]

# %%
#Scenario: Each record contains daily hours of study, entertainment, and sleep.
#1. Create empty lists for study_hours, entertainment_hours, and sleep_hours.
study_hours = []
entertainment_hours = []
sleep_hours = []
#2. Iterate over time_data and extract values into each list.
for study, ent, sleep in time_data:
    study_hours.append(study)
    entertainment_hours.append(ent)
    sleep_hours.append(sleep)
#3. Calculate and print:
#(a) Average hours spent studying.
avg_study = sum(study_hours) / len(study_hours)
#(b) Average hours spent on entertainment.
avg_entertainment = sum(entertainment_hours) / len(entertainment_hours)
#(c) Average hours spent sleeping.
avg_sleep = sum(sleep_hours) / len(sleep_hours)

#Printing results:
print("Average Study Hours:", avg_study)
print("Average Entertainment Hours:", avg_entertainment)
print("Average Sleep Hours:", avg_sleep)
# Out:
# Average Study Hours: 3.7
# Average Entertainment Hours: 2.5
# Average Sleep Hours: 7.166666666666667

# %%
#1. Import matplotlib.pyplot as plt.
import matplotlib.pyplot as plt
#2. Plot a scatter plot with:
#labels
#• x-axis: Study hours
plt.xlabel("Study Hours")
#• y-axis: Sleep hours
plt.ylabel("Sleep Hours")
#3. Add labels, title, and color.
#title
plt.title("Study Hours vs Sleep Hours")
#color
plt.scatter(study_hours, sleep_hours, color='red')
plt.grid(True)
#Showing the plot.
plt.show()
